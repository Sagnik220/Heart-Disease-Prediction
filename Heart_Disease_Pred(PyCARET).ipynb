# %% [markdown]
# <a href="https://colab.research.google.com/github/Sagnik220/Heart-Disease-Prediction/blob/main/Heart_Disease_Pred(PyCARET).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pycaret.datasets import get_data
data = get_data('heart')
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1   37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2   41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3   56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4   57    0   0       120   354    0  ...      1      0.6      2   0     2       1
#
# [5 rows x 14 columns]

# %%
from pycaret.classification import *
s = setup(data, target = 'target')
# Out:
#                                Description             Value
# 0                               session_id              1660
# 1                                   Target            target
# 2                              Target Type            Binary
# 3                            Label Encoded        0: 0, 1: 1
# 4                            Original Data         (303, 14)
# 5                           Missing Values             False
# 6                         Numeric Features                 5
# 7                     Categorical Features                 8
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (212, 27)
# 12                    Transformed Test Set          (91, 27)
# 13                      Shuffle Train-Test              True
# ...

# %%
best_model=compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.8439  0.9061  0.8833  0.8316
# lightgbm  Light Gradient Boosting Machine    0.8435  0.8854  0.8735  0.8447
# ridge                    Ridge Classifier    0.8344  0.0000  0.8924  0.8135
# lda          Linear Discriminant Analysis    0.8344  0.9042  0.8924  0.8135
# rf               Random Forest Classifier    0.8340  0.9108  0.8288  0.8575
# et                 Extra Trees Classifier    0.8249  0.9161  0.8477  0.8287
# gbc          Gradient Boosting Classifier    0.7777  0.8771  0.8114  0.7788
# ada                  Ada Boost Classifier    0.7732  0.8572  0.7848  0.7865
# dt               Decision Tree Classifier    0.7496  0.7505  0.7409  0.7836
# nb                            Naive Bayes    0.7452  0.8658  0.9212  0.7013
# knn                K Neighbors Classifier    0.6561  0.6766  0.7144  0.6613
# ...

# %%
print(best_model)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=1660, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
logistic_regression_model=create_model('lr', fold = 20)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.9091  1.0000  1.0000  0.8571  0.9231  0.8136  0.8281
# 1       0.8182  0.9667  0.8333  0.8333  0.8333  0.6333  0.6333
# 2       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 3       0.8182  0.9333  0.8333  0.8333  0.8333  0.6333  0.6333
# 4       0.8182  0.8667  0.8333  0.8333  0.8333  0.6333  0.6333
# 5       0.7273  0.9333  0.6667  0.8000  0.7273  0.4590  0.4667
# 6       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 7       0.7273  0.9333  0.8333  0.7143  0.7692  0.4407  0.4485
# 8       0.9091  1.0000  1.0000  0.8571  0.9231  0.8136  0.8281
# 9       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 10      0.8182  0.7667  0.8333  0.8333  0.8333  0.6333  0.6333
# 11      0.7273  0.8000  0.8333  0.7143  0.7692  0.4407  0.4485
# 12      1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 13      0.8000  0.9200  1.0000  0.7143  0.8333  0.6000  0.6547
# ...

# %%
tuned_logistic_regression=tune_model(logistic_regression_model,optimize='Accuracy')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.9091  0.9833  0.9167  0.9167  0.9167  0.8167  0.8167
# 1       0.9091  0.9417  0.9167  0.9167  0.9167  0.8167  0.8167
# 2       0.8095  0.9091  0.8182  0.8182  0.8182  0.6182  0.6182
# 3       0.8095  0.9455  0.8182  0.8182  0.8182  0.6182  0.6182
# 4       0.9524  0.9909  1.0000  0.9167  0.9565  0.9041  0.9083
# 5       0.7619  0.7455  0.8182  0.7500  0.7826  0.5205  0.5230
# 6       0.9048  0.9455  1.0000  0.8462  0.9167  0.8073  0.8228
# 7       0.8095  0.8818  0.8182  0.8182  0.8182  0.6182  0.6182
# 8       0.8571  0.8727  1.0000  0.7857  0.8800  0.7097  0.7416
# 9       0.7619  0.8818  0.7273  0.8000  0.7619  0.5249  0.5273
# Mean    0.8485  0.9098  0.8833  0.8386  0.8586  0.6954  0.7011
# SD      0.0640  0.0674  0.0919  0.0563  0.0634  0.1278  0.1299

# %%
plot_model(logistic_regression_model,'confusion_matrix')

# %%
plot_model(logistic_regression_model,'error')

# %%
plot_model(logistic_regression_model,'feature')

# %%
plot_model(logistic_regression_model,'learning')

# %%
plot_model(logistic_regression_model,'auc')
